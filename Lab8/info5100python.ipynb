# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
video_game_sale = pd.read_csv('vgsales.csv')

# %%
video_game_sale
# Out:
#         Rank                                              Name Platform  \
# 0          1                                        Wii Sports      Wii
# 1          2                                 Super Mario Bros.      NES
# 2          3                                    Mario Kart Wii      Wii
# 3          4                                 Wii Sports Resort      Wii
# 4          5                          Pokemon Red/Pokemon Blue       GB
# ...      ...                                               ...      ...
# 16593  16596                Woody Woodpecker in Crazy Castle 5      GBA
# 16594  16597                     Men in Black II: Alien Escape       GC
# 16595  16598  SCORE International Baja 1000: The Official Game      PS2
# 16596  16599                                        Know How 2       DS
# 16597  16600                                  Spirits & Spells      GBA
#
#          Year         Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  \
# 0      2006.0        Sports    Nintendo     41.49     29.02      3.77
# 1      1985.0      Platform    Nintendo     29.08      3.58      6.81
# 2      2008.0        Racing    Nintendo     15.85     12.88      3.79
# 3      2009.0        Sports    Nintendo     15.75     11.01      3.28
# 4      1996.0  Role-Playing    Nintendo     11.27      8.89     10.22
# ...       ...           ...         ...       ...       ...       ...
# 16593  2002.0      Platform       Kemco      0.01      0.00      0.00
# 16594  2003.0       Shooter  Infogrames      0.01      0.00      0.00
# 16595  2008.0        Racing  Activision      0.00      0.00      0.00
# 16596  2010.0        Puzzle    7G//AMES      0.00      0.01      0.00
# 16597  2003.0      Platform     Wanadoo      0.01      0.00      0.00
#
#        Other_Sales  Global_Sales
# 0             8.46         82.74
# 1             0.77         40.24
# 2             3.31         35.82
# 3             2.96         33.00
# 4             1.00         31.37
# ...            ...           ...
# 16593         0.00          0.01
# 16594         0.00          0.01
# 16595         0.00          0.01
# 16596         0.00          0.01
# 16597         0.00          0.01
#
# [16598 rows x 11 columns]

# %%
video_game_sale.head(-10)
# Out:
#         Rank                            Name Platform    Year         Genre  \
# 0          1                      Wii Sports      Wii  2006.0        Sports
# 1          2               Super Mario Bros.      NES  1985.0      Platform
# 2          3                  Mario Kart Wii      Wii  2008.0        Racing
# 3          4               Wii Sports Resort      Wii  2009.0        Sports
# 4          5        Pokemon Red/Pokemon Blue       GB  1996.0  Role-Playing
# ...      ...                             ...      ...     ...           ...
# 16583  16586                  Carmageddon 64      N64  1999.0        Action
# 16584  16587                Bust-A-Move 3000       GC  2003.0        Puzzle
# 16585  16588                          Breach       PC  2011.0       Shooter
# 16586  16589  Secret Files 2: Puritas Cordis       DS  2009.0     Adventure
# 16587  16590        Mezase!! Tsuri Master DS       DS  2009.0        Sports
#
#                 Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# 0                Nintendo     41.49     29.02      3.77         8.46
# 1                Nintendo     29.08      3.58      6.81         0.77
# 2                Nintendo     15.85     12.88      3.79         3.31
# 3                Nintendo     15.75     11.01      3.28         2.96
# 4                Nintendo     11.27      8.89     10.22         1.00
# ...                   ...       ...       ...       ...          ...
# 16583  Virgin Interactive      0.01      0.00      0.00         0.00
# 16584             Ubisoft      0.01      0.00      0.00         0.00
# 16585           Destineer      0.01      0.00      0.00         0.00
# 16586         Deep Silver      0.00      0.01      0.00         0.00
# 16587         Hudson Soft      0.00      0.00      0.01         0.00
#
#        Global_Sales
# 0             82.74
# 1             40.24
# 2             35.82
# 3             33.00
# 4             31.37
# ...             ...
# 16583          0.01
# 16584          0.01
# 16585          0.01
# 16586          0.01
# 16587          0.01
#
# [16588 rows x 11 columns]

# %%
video_game_sale.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16598 entries, 0 to 16597
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Rank          16598 non-null  int64
#  1   Name          16598 non-null  object
#  2   Platform      16598 non-null  object
#  3   Year          16327 non-null  float64
#  4   Genre         16598 non-null  object
#  5   Publisher     16540 non-null  object
#  6   NA_Sales      16598 non-null  float64
#  7   EU_Sales      16598 non-null  float64
#  8   JP_Sales      16598 non-null  float64
#  9   Other_Sales   16598 non-null  float64
#  10  Global_Sales  16598 non-null  float64
# dtypes: float64(6), int64(1), object(4)
# memory usage: 1.4+ MB

# %%
video_game_sale["NA_Sales"].value_counts()
# Out:
# NA_Sales
# 0.00    4499
# 0.02     550
# 0.01     541
# 0.03     533
# 0.05     530
#         ...
# 2.97       1
# 2.54       1
# 2.95       1
# 3.28       1
# 3.19       1
# Name: count, Length: 409, dtype: int64

# %%
plt.plot(video_game_sale['Name'], video_game_sale['NA_Sales'])
plt.title("Games Sales")
plt.xlabel("Name")
plt.ylabel("North America Sales")
plt.xticks(rotation=90)  
plt.tight_layout()  
plt.savefig("game_sales_chart.png", dpi=300)  
plt.show()
# Out:
# /var/folders/rf/txxtnd7d743d41hnvdlr62_40000gn/T/ipykernel_7187/278013713.py:6: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all Axes decorations.
#   plt.tight_layout()  # Adjust layout to prevent clipping

# %%
plt.grid(True)

plt.plot(video_game_sale["Name"], video_game_sale['NA_Sales'])
plt.title("Video Game Sales in North America")
plt.xlabel("Name")
plt.ylabel("NA_Salse")
# Set x-axis for every 10 units
plt.xticks(range(0, max(video_game_sale["Rank"]) + 1, 10))  
plt.savefig("GameSales.png", dpi=300)
plt.show()

# %%
sns.histplot(data=video_game_sale, x="Genre")
plt.title("Sales Distribution")
plt.xlabel("Genre")
plt.ylabel("Count")
plt.savefig("VideGameGenreSales.png",dpi=300)

# %%
sns.pairplot(video_game_sale, hue="Genre")
plt.savefig("VideGameGenreSalesGraphs.png",dpi=300)
plt.show()

# %%
# Create a KDE plot
plt.figure(figsize=(8, 6))
sns.kdeplot(data=video_game_sale, x="Global_Sales", hue="Genre", fill=True, common_norm=False, palette="crest", alpha=0.2)

# Add labels and title
plt.title("Sales based on different Genre")
plt.xlabel("Genre")
plt.ylabel("Sales")
plt.savefig("GlobalsSales.png",dpi=300)
plt.show()

# %%
plt.grid(True)
plt.scatter(video_game_sale["NA_Sales"], video_game_sale["EU_Sales"])
plt.title("NA_Sales vs EU_Sales")
plt.xlabel("NA_Sales")
plt.ylabel("EU_Sales")
plt.savefig("NA_Sales vs EU_Sales.png",dpi=300)

# %%
plt.grid(True)

plt.plot(video_game_sale["Rank"], video_game_sale['Global_Sales'])
plt.title("Global_Sales")
plt.xlabel("Rank")
plt.ylabel("Global_Sales")
# Set x-axis for every 10 units
plt.xticks(range(0, max(video_game_sale["Rank"]) + 1, 10))  
plt.savefig("GlobalSalesPlot.png", dpi=300)
plt.show()
